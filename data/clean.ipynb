# %% [markdown]
# # Cleaning the csv data

# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv("20220423-Olsen-1.csv")

# %%
df.head()
# Out:
#    PitchNo        Date         Time  PAofInning  PitchofPA        Pitcher  \
# 0        1  2022-04-23  14:02:20.23           1          1  Dallas, Micah
# 1        2  2022-04-23  14:02:56.33           2          1  Dallas, Micah
# 2        3  2022-04-23  14:03:16.64           2          2  Dallas, Micah
# 3        4  2022-04-23  14:03:32.58           2          3  Dallas, Micah
# 4        5  2022-04-23  14:03:48.06           2          4  Dallas, Micah
#
#     PitcherId PitcherThrows PitcherTeam          Batter  ...  \
# 0  1000058245         Right     TEX_AGG   Webb, Braydon  ...
# 1  1000058245         Right     TEX_AGG  Slavens, Brady  ...
# 2  1000058245         Right     TEX_AGG  Slavens, Brady  ...
# 3  1000058245         Right     TEX_AGG  Slavens, Brady  ...
# 4  1000058245         Right     TEX_AGG  Slavens, Brady  ...
#
#    ThrowTrajectoryZc1 ThrowTrajectoryZc2 PitchReleaseConfidence  \
# 0                 NaN                NaN                   High
# ...

# %%
pprint(df.columns)
# Out:
# Index(['PitchNo', 'Date', 'Time', 'PAofInning', 'PitchofPA', 'Pitcher',
#        'PitcherId', 'PitcherThrows', 'PitcherTeam', 'Batter',
#        ...
#        'ThrowTrajectoryZc1', 'ThrowTrajectoryZc2', 'PitchReleaseConfidence',
#        'HitLaunchConfidence', 'HitLandingConfidence',
#        'CatcherThrowCatchConfidence', 'PitchLocationConfidence',
#        'CatcherThrowLocationConfidence', 'CatcherThrowReleaseConfidence',
#        'PitchMovementConfidence'],
#       dtype='object', length=167)
